# %% [markdown]
# ### Transfer learning
# https://github.com/hasibzunair/segmentation_models

# %%
from segmentation_models import Unet
# Out:
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %% [markdown]
# #### TRAIN FROM SCRATCH

# %%
# define number of channels
N = 1

# define model
BACKBONE = 'resnet34'
model = Unet(backbone_name=BACKBONE, encoder_weights=None, input_shape=(320, 320, N))

model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 320, 320, 1)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 320, 320, 1)  3           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_87 (ZeroPadding2 (None, 326, 326, 1)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 160, 160, 64) 3136        zero_padding2d_87[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 160, 160, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 160, 160, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_88 (ZeroPadding2 (None, 162, 162, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 80, 80, 64)   0           zero_padding2d_88[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 80, 80, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 80, 80, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_89 (ZeroPadding2 (None, 82, 82, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 80, 80, 64)   36864       zero_padding2d_89[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 80, 80, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 80, 80, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_90 (ZeroPadding2 (None, 82, 82, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 80, 80, 64)   36864       zero_padding2d_90[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 80, 80, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 80, 80, 64)   0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 80, 80, 64)   256         add_41[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 80, 80, 64)   0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_91 (ZeroPadding2 (None, 82, 82, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 80, 80, 64)   36864       zero_padding2d_91[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 80, 80, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 80, 80, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_92 (ZeroPadding2 (None, 82, 82, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 80, 80, 64)   36864       zero_padding2d_92[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 80, 80, 64)   0           stage1_unit2_conv2[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 80, 80, 64)   256         add_42[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 80, 80, 64)   0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_93 (ZeroPadding2 (None, 82, 82, 64)   0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 80, 80, 64)   36864       zero_padding2d_93[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 80, 80, 64)   256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 80, 80, 64)   0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_94 (ZeroPadding2 (None, 82, 82, 64)   0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 80, 80, 64)   36864       zero_padding2d_94[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 80, 80, 64)   0           stage1_unit3_conv2[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 80, 80, 64)   256         add_43[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 80, 80, 64)   0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_95 (ZeroPadding2 (None, 82, 82, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 40, 40, 128)  73728       zero_padding2d_95[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 40, 40, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 40, 40, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_96 (ZeroPadding2 (None, 42, 42, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_96[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 40, 40, 128)  8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 40, 40, 128)  0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 40, 40, 128)  512         add_44[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 40, 40, 128)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_97 (ZeroPadding2 (None, 42, 42, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_97[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 40, 40, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 40, 40, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_98 (ZeroPadding2 (None, 42, 42, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_98[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 40, 40, 128)  0           stage2_unit2_conv2[0][0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 40, 40, 128)  512         add_45[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 40, 40, 128)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_99 (ZeroPadding2 (None, 42, 42, 128)  0           stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_99[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 40, 40, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 40, 40, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_100 (ZeroPadding (None, 42, 42, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_100[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 40, 40, 128)  0           stage2_unit3_conv2[0][0]
#                                                                  add_45[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 40, 40, 128)  512         add_46[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 40, 40, 128)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_101 (ZeroPadding (None, 42, 42, 128)  0           stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_101[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 40, 40, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 40, 40, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_102 (ZeroPadding (None, 42, 42, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 40, 40, 128)  147456      zero_padding2d_102[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 40, 40, 128)  0           stage2_unit4_conv2[0][0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 40, 40, 128)  512         add_47[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 40, 40, 128)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_103 (ZeroPadding (None, 42, 42, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 20, 20, 256)  294912      zero_padding2d_103[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 20, 20, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 20, 20, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_104 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_104[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 20, 20, 256)  32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 20, 20, 256)  0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 20, 20, 256)  1024        add_48[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 20, 20, 256)  0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_105 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_105[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 20, 20, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 20, 20, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_106 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_106[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 20, 20, 256)  0           stage3_unit2_conv2[0][0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 20, 20, 256)  1024        add_49[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 20, 20, 256)  0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_107 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_107[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 20, 20, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 20, 20, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_108 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_108[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 20, 20, 256)  0           stage3_unit3_conv2[0][0]
#                                                                  add_49[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 20, 20, 256)  1024        add_50[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 20, 20, 256)  0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_109 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_109[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 20, 20, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 20, 20, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_110 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_110[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 20, 20, 256)  0           stage3_unit4_conv2[0][0]
#                                                                  add_50[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 20, 20, 256)  1024        add_51[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 20, 20, 256)  0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_111 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_111[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 20, 20, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 20, 20, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_112 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_112[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 20, 20, 256)  0           stage3_unit5_conv2[0][0]
#                                                                  add_51[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 20, 20, 256)  1024        add_52[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 20, 20, 256)  0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_113 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_113[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 20, 20, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 20, 20, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_114 (ZeroPadding (None, 22, 22, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 20, 20, 256)  589824      zero_padding2d_114[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 20, 20, 256)  0           stage3_unit6_conv2[0][0]
#                                                                  add_52[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 20, 20, 256)  1024        add_53[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 20, 20, 256)  0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_115 (ZeroPadding (None, 22, 22, 256)  0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 10, 10, 512)  1179648     zero_padding2d_115[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 10, 10, 512)  2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 10, 10, 512)  0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_116 (ZeroPadding (None, 12, 12, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 10, 10, 512)  2359296     zero_padding2d_116[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 10, 10, 512)  131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 10, 10, 512)  0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 10, 10, 512)  2048        add_54[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 10, 10, 512)  0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_117 (ZeroPadding (None, 12, 12, 512)  0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 10, 10, 512)  2359296     zero_padding2d_117[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 10, 10, 512)  2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 10, 10, 512)  0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_118 (ZeroPadding (None, 12, 12, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 10, 10, 512)  2359296     zero_padding2d_118[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 10, 10, 512)  0           stage4_unit2_conv2[0][0]
#                                                                  add_54[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 10, 10, 512)  2048        add_55[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 10, 10, 512)  0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_119 (ZeroPadding (None, 12, 12, 512)  0           stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 10, 10, 512)  2359296     zero_padding2d_119[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 10, 10, 512)  2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 10, 10, 512)  0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_120 (ZeroPadding (None, 12, 12, 512)  0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 10, 10, 512)  2359296     zero_padding2d_120[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 10, 10, 512)  0           stage4_unit3_conv2[0][0]
#                                                                  add_55[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 10, 10, 512)  2048        add_56[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 10, 10, 512)  0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 20, 20, 512)  0           relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 20, 20, 768)  0           decoder_stage0_upsampling[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 20, 20, 256)  1769472     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 20, 20, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 20, 20, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 20, 20, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 20, 20, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 20, 20, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 40, 40, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 40, 40, 384)  0           decoder_stage1_upsampling[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 40, 40, 128)  442368      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 40, 40, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 40, 40, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 40, 40, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 40, 40, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 40, 40, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 80, 80, 128)  0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 80, 80, 192)  0           decoder_stage2_upsampling[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 80, 80, 64)   110592      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 80, 80, 64)   256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 80, 80, 64)   0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 80, 80, 64)   36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 80, 80, 64)   256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 80, 80, 64)   0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 160, 160, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 160, 160, 128 0           decoder_stage3_upsampling[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 160, 160, 32) 36864       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 160, 160, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 160, 160, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 160, 160, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 160, 160, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 160, 160, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 320, 320, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 320, 320, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 320, 320, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 320, 320, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 320, 320, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 320, 320, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 320, 320, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 320, 320, 1)  145         decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 320, 320, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 24,449,876
# Trainable params: 24,432,530
# Non-trainable params: 17,346
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train with pretrained weights

# %%
from segmentation_models import Unet
from keras.layers import Input, Conv2D
from keras.models import Model

# define number of channels
N = 1

# setup base pretrained model
base_model = Unet(backbone_name='resnet34', encoder_weights='imagenet')

inp = Input(shape=(320, 320, N))
l1 = Conv2D(3, (1, 1))(inp) # map N channels data to 3 channels
out = base_model(l1)

model = Model(inp, out, name=base_model.name)
print(model.summary())
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 320, 320, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 320, 320, 3)       6
# _________________________________________________________________
# model_4 (Model)              multiple                  24456154
# =================================================================
# Total params: 24,456,160
# Trainable params: 24,438,810
# Non-trainable params: 17,350
# _________________________________________________________________
# None

# %% [markdown]
# ### Fine tuning

# %%
#from segmentation_models import Unet
#from segmentation_models.utils import set_trainable

# freeze_encoder=True -->> backbone is frozen

#model = Unet(backbone_name='resnet34', encoder_weights='imagenet', freeze_encoder=True)
#model.compile('Adam', 'binary_crossentropy', ['binary_accuracy'])

# pretrain model decoder
#model.fit(x, y, epochs=2)

# release all layers for training
#set_trainable(model) # set all layers trainable and recompile model

# continue training
#model.fit(x, y, epochs=100)

# %% [markdown]
# ### FPN

# %%
import segmentation_models as sm

# define number of channels
N = 1

# setup base pretrained model
base_model = sm.FPN(backbone_name='resnet18', encoder_weights='imagenet')

inp = Input(shape=(320, 320, N))
l1 = Conv2D(3, (1, 1))(inp) # map N channels data to 3 channels
out = base_model(l1)

model = Model(inp, out, name=base_model.name)
print(model.summary())
# Out:
# WARNING:tensorflow:From /home/hasib/anaconda3/envs/seg/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2241: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 320, 320, 1)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 320, 320, 3)       6
# _________________________________________________________________
# model_6 (Model)              multiple                  13838430
# =================================================================
# Total params: 13,838,436
# Trainable params: 13,828,190
# Non-trainable params: 10,246
# _________________________________________________________________
# None

# %%
#x = model.layers[-1]
#for l in x.layers:
    #print(l)
