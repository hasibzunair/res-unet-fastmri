# %% [markdown]
# ### Test script

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy
from glob import glob
import numpy as np
import cv2

# %%
#img = cv2.imread(path, 0) / 255.0

# %%
img = cv2.imread("datasets/singlecoil_train_2D_images_normalized/trainB/2_19.png", 0) / 255.0
img.shape
# Out:
# (320, 320)

# %%
#img = np.expand_dims(img, axis=2)
#img.shape
# Out:
# (320, 320, 1)

# %%
flat = img.flatten()
MIN_BOUND = min(flat)
MAX_BOUND = max(flat)

MIN_BOUND, MAX_BOUND
# Out:
# (0.0, 1.0)

# %%
plt.imshow(img, cmap='gray')

# %%
def load_img( path):
    img = imread(path)
    img = scipy.misc.imresize(img, self.img_res)
    img = img/127.5 - 1.
    return img[np.newaxis, :, :, :]

def imread( path):
    return scipy.misc.imread(path, mode='L').astype(np.float) #RGB

# %%
#x = load_img("datasets/singlecoil_train_2D_images/trainA/" + img)
#x.shape

x = cv2.imread("datasets/singlecoil_train_2D_images/trainA/" + img)
x.shape
# Out:
# (320, 320, 3)
