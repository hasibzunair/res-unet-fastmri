# %%
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import h5py
import helpers as H
from fastMRI.data import transforms as T
from fastMRI.common.subsample import MaskFunc

#Root directory of the project
ROOT_DIR = os.path.abspath(".")
TEST_DATASET_PATH = os.path.join(ROOT_DIR, "dataset")
test_h5_files = glob.glob(os.path.join(TEST_DATASET_PATH,'singlecoil_test_v2','*.h5'))
print(len(test_h5_files))
# Out:
# 108

# %%
def sub_sample_kspace(vol, mask_func):
    """
    Transform a kpsace tensor to an undersampled 3D image using mask object 4x or 8x.
    Args:
        vol: kspace tensor
        mask_func: mask function object (4x, 8x)
    Returns:
        sampled_image: output undersampled 3D image volume
    """
    
    # 1. convert numpy to torch tensor
    kspace2ttensor = T.to_tensor(vol)
    
    # 2. apply mask to kspace
    #masked_kspace, mask = T.apply_mask(kspace2ttensor, mask_func)   
    
    # 3. inverse fast fourier transform 2D
    sampled_image = T.ifft2(kspace2ttensor)
    
    # 4. compute absolute value to get a real image
    sampled_image_abs = T.complex_abs(sampled_image)
    
    # 5. centre crop to 320x320
    cropped_image = T.center_crop(sampled_image_abs, (320, 320))
    
    # 6. Normalize
    #cropped_image_norm, _, _ = T.normalize_instance(cropped_image)

    # 7. convert torch tensor to good old numpy array
    sampled_image = np.abs(cropped_image.numpy())
    
    return sampled_image


def show_slices(data, slice_nums, cmap=None):
    fig = plt.figure(figsize=(16, 16))
    for i, num in enumerate(slice_nums):
        plt.subplot(1, len(slice_nums), i + 1)
        plt.imshow(data[num], cmap=cmap)

# %% [markdown]
# ### Get a single MRI file

# %%
test_h5_files[0]
# Out:
# 'E:\\FastMRI\\MRI-reconstruction\\dataset\\singlecoil_test_v2\\file1000022_v2.h5'

# %%
file = test_h5_files[6]
hf = h5py.File(file)
print(type(hf))
# Out:
# <class 'h5py._hl.files.File'>

# %%
# Create a mask function object for undersampling

mask_func = MaskFunc(center_fractions=[0.04, 0.08], accelerations=[8, 4])
mask_func_4x = MaskFunc(center_fractions=[0.08], accelerations=[4])
mask_func_8x = MaskFunc(center_fractions=[0.04], accelerations=[8])

# %% [markdown]
# ### 1. Kspace tensor

# %%
kspace_tensor = hf['kspace'][()]
print(kspace_tensor.shape)
img_3d = sub_sample_kspace(kspace_tensor, mask_func)
print(img_3d.shape)
# Out:
# (33, 640, 372)
# (33, 320, 320)

# %%
slice_num = [12, 16, 19, 22, 24]
show_slices(img_3d, slice_num, cmap='gray')

# %%
TEST_LOW_DIR = "singlecoil_train_3D_images_48x/low/"
H.create_directory("{}/{}".format(TEST_DATASET_PATH, TEST_LOW_DIR))

# %%
LOW_DIR_PATH = os.path.join(TRAIN_DATASET_PATH, LOW_DIR)
LOW_DIR_PATH
# Out:
# ('E:\\FastMRI\\MRI-reconstruction\\dataset\\singlecoil_train_3D_images_48x/low/',
#  'E:\\FastMRI\\MRI-reconstruction\\dataset\\singlecoil_train_3D_images_48x/high/')

# %%
len(train_h5_files)
# Out:
# 973

# %%
i=0
for file in train_h5_files:
    i+=1
    
    hf = h5py.File(file)
    
    # transform and save low res image
    kspace_tensor = hf['kspace'][()]
    img_3d = sub_sample_kspace(kspace_tensor, mask_func) # 4x, 8x acceleration (NOW 4x8x acceleration)

    # Save X 
    np.save("{}/{}.npy".format(LOW_DIR_PATH, i), img_3d)

    
    # transform and save ground truth(RSS)
    gt_rss = hf['reconstruction_rss']
    img_3d_gt = recon_ground_truth(gt_rss)
    
    # Save Y
    np.save("{}/{}.npy".format(HIGH_DIR_PATH, i), img_3d_gt)
    
    # Show progress
    print(i, file[-15:], "raw data - ", kspace_tensor.shape, "--", "input volume - ", img_3d.shape, "--", "output volume - ", img_3d_gt.shape)
# Out:
# 1 \file1000001.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 2 \file1000002.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 3 \file1000003.h5 raw data -  (45, 640, 368) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 4 \file1000005.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 5 \file1000010.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 6 \file1000012.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 7 \file1000015.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 8 \file1000021.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 9 \file1000023.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 10 \file1000027.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 11 \file1000029.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 12 \file1000032.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 13 \file1000039.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 14 \file1000040.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 15 \file1000043.h5 raw data -  (41, 640, 372) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 16 \file1000045.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 17 \file1000048.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 18 \file1000053.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 19 \file1000057.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 20 \file1000058.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 21 \file1000059.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 22 \file1000060.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 23 \file1000061.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 24 \file1000064.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 25 \file1000065.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 26 \file1000066.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 27 \file1000069.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 28 \file1000070.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 29 \file1000075.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 30 \file1000081.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 31 \file1000084.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 32 \file1000085.h5 raw data -  (45, 640, 372) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 33 \file1000086.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 34 \file1000088.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 35 \file1000089.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 36 \file1000090.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 37 \file1000094.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 38 \file1000097.h5 raw data -  (36, 640, 356) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 39 \file1000098.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 40 \file1000100.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 41 \file1000101.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 42 \file1000109.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 43 \file1000111.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 44 \file1000115.h5 raw data -  (44, 640, 368) -- input volume -  (44, 320, 320) -- output volume -  (44, 320, 320)
# 45 \file1000116.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 46 \file1000117.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 47 \file1000120.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 48 \file1000123.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 49 \file1000125.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 50 \file1000127.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 51 \file1000129.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 52 \file1000131.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 53 \file1000138.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 54 \file1000141.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 55 \file1000142.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 56 \file1000143.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 57 \file1000148.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 58 \file1000149.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 59 \file1000154.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 60 \file1000159.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 61 \file1000161.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 62 \file1000167.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 63 \file1000170.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 64 \file1000172.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 65 \file1000173.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 66 \file1000176.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 67 \file1000177.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 68 \file1000179.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 69 \file1000180.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 70 \file1000181.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 71 \file1000185.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 72 \file1000188.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 73 \file1000191.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 74 \file1000193.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 75 \file1000195.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 76 \file1000198.h5 raw data -  (42, 640, 372) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 77 \file1000199.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 78 \file1000200.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 79 \file1000204.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 80 \file1000205.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 81 \file1000207.h5 raw data -  (43, 640, 368) -- input volume -  (43, 320, 320) -- output volume -  (43, 320, 320)
# 82 \file1000208.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 83 \file1000210.h5 raw data -  (30, 640, 368) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 84 \file1000211.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 85 \file1000213.h5 raw data -  (41, 640, 368) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 86 \file1000216.h5 raw data -  (38, 640, 400) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 87 \file1000220.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 88 \file1000221.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 89 \file1000222.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 90 \file1000223.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 91 \file1000224.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 92 \file1000225.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 93 \file1000231.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 94 \file1000233.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 95 \file1000236.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 96 \file1000237.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 97 \file1000242.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 98 \file1000244.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 99 \file1000245.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 100 \file1000246.h5 raw data -  (40, 640, 322) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 101 \file1000248.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 102 \file1000249.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 103 \file1000250.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 104 \file1000252.h5 raw data -  (45, 640, 368) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 105 \file1000256.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 106 \file1000257.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 107 \file1000259.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 108 \file1000261.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 109 \file1000262.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 110 \file1000265.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 111 \file1000271.h5 raw data -  (48, 640, 640) -- input volume -  (48, 320, 320) -- output volume -  (48, 320, 320)
# 112 \file1000275.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 113 \file1000284.h5 raw data -  (38, 640, 372) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 114 \file1000285.h5 raw data -  (43, 640, 368) -- input volume -  (43, 320, 320) -- output volume -  (43, 320, 320)
# 115 \file1000287.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 116 \file1000289.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 117 \file1000290.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 118 \file1000293.h5 raw data -  (34, 640, 388) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 119 \file1000296.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 120 \file1000298.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 121 \file1000300.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 122 \file1000301.h5 raw data -  (44, 640, 372) -- input volume -  (44, 320, 320) -- output volume -  (44, 320, 320)
# 123 \file1000306.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 124 \file1000307.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 125 \file1000311.h5 raw data -  (30, 640, 322) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 126 \file1000313.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 127 \file1000315.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 128 \file1000317.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 129 \file1000321.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 130 \file1000324.h5 raw data -  (32, 640, 368) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 131 \file1000326.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 132 \file1000330.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 133 \file1000331.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 134 \file1000335.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 135 \file1000336.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 136 \file1000338.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 137 \file1000339.h5 raw data -  (41, 640, 368) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 138 \file1000340.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 139 \file1000342.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 140 \file1000347.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 141 \file1000349.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 142 \file1000351.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 143 \file1000354.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 144 \file1000357.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 145 \file1000363.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 146 \file1000365.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 147 \file1000369.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 148 \file1000371.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 149 \file1000372.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 150 \file1000374.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 151 \file1000376.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 152 \file1000378.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 153 \file1000381.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 154 \file1000382.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 155 \file1000383.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 156 \file1000384.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 157 \file1000390.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 158 \file1000393.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 159 \file1000400.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 160 \file1000401.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 161 \file1000402.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 162 \file1000403.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 163 \file1000408.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 164 \file1000410.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 165 \file1000412.h5 raw data -  (39, 640, 388) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 166 \file1000416.h5 raw data -  (40, 640, 372) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 167 \file1000418.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 168 \file1000420.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 169 \file1000424.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 170 \file1000425.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 171 \file1000426.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 172 \file1000427.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 173 \file1000428.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 174 \file1000434.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 175 \file1000443.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 176 \file1000448.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 177 \file1000449.h5 raw data -  (40, 640, 372) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 178 \file1000452.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 179 \file1000458.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 180 \file1000459.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 181 \file1000461.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 182 \file1000467.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 183 \file1000472.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 184 \file1000475.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 185 \file1000479.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 186 \file1000481.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 187 \file1000482.h5 raw data -  (40, 640, 372) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 188 \file1000483.h5 raw data -  (31, 640, 368) -- input volume -  (31, 320, 320) -- output volume -  (31, 320, 320)
# 189 \file1000485.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 190 \file1000486.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 191 \file1000489.h5 raw data -  (32, 640, 368) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 192 \file1000490.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 193 \file1000492.h5 raw data -  (35, 640, 322) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 194 \file1000493.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 195 \file1000495.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 196 \file1000499.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 197 \file1000501.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 198 \file1000504.h5 raw data -  (29, 640, 372) -- input volume -  (29, 320, 320) -- output volume -  (29, 320, 320)
# 199 \file1000508.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 200 \file1000509.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 201 \file1000510.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 202 \file1000511.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 203 \file1000514.h5 raw data -  (38, 640, 388) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 204 \file1000517.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 205 \file1000518.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 206 \file1000521.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 207 \file1000529.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 208 \file1000535.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 209 \file1000539.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 210 \file1000540.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 211 \file1000547.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 212 \file1000548.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 213 \file1000550.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 214 \file1000554.h5 raw data -  (41, 640, 368) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 215 \file1000557.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 216 \file1000558.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 217 \file1000559.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 218 \file1000560.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 219 \file1000561.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 220 \file1000563.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 221 \file1000566.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 222 \file1000568.h5 raw data -  (29, 640, 372) -- input volume -  (29, 320, 320) -- output volume -  (29, 320, 320)
# 223 \file1000569.h5 raw data -  (42, 640, 338) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 224 \file1000573.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 225 \file1000582.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 226 \file1000583.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 227 \file1000584.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 228 \file1000585.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 229 \file1000586.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 230 \file1000587.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 231 \file1000588.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 232 \file1000590.h5 raw data -  (32, 640, 368) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 233 \file1000592.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 234 \file1000597.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 235 \file1000600.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 236 \file1000601.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 237 \file1000602.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 238 \file1000605.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 239 \file1000610.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 240 \file1000611.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 241 \file1000612.h5 raw data -  (45, 640, 372) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 242 \file1000615.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 243 \file1000617.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 244 \file1000619.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 245 \file1000626.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 246 \file1000627.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 247 \file1000632.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 248 \file1000633.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 249 \file1000637.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 250 \file1000638.h5 raw data -  (36, 640, 370) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 251 \file1000639.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 252 \file1000640.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 253 \file1000643.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 254 \file1000653.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 255 \file1000658.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 256 \file1000661.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 257 \file1000662.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 258 \file1000663.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 259 \file1000682.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 260 \file1000685.h5 raw data -  (29, 640, 372) -- input volume -  (29, 320, 320) -- output volume -  (29, 320, 320)
# 261 \file1000689.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 262 \file1000691.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 263 \file1000693.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 264 \file1000695.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 265 \file1000708.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 266 \file1000709.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 267 \file1000715.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 268 \file1000716.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 269 \file1000719.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 270 \file1000721.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 271 \file1000723.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 272 \file1000728.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 273 \file1000734.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 274 \file1000736.h5 raw data -  (41, 640, 372) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 275 \file1000738.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 276 \file1000740.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 277 \file1000742.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 278 \file1000743.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 279 \file1000750.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 280 \file1000752.h5 raw data -  (33, 640, 322) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 281 \file1000753.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 282 \file1000754.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 283 \file1000755.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 284 \file1000760.h5 raw data -  (43, 640, 368) -- input volume -  (43, 320, 320) -- output volume -  (43, 320, 320)
# 285 \file1000762.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 286 \file1000768.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 287 \file1000770.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 288 \file1000776.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 289 \file1000777.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 290 \file1000778.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 291 \file1000784.h5 raw data -  (41, 640, 372) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 292 \file1000785.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 293 \file1000790.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 294 \file1000794.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 295 \file1000795.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 296 \file1000801.h5 raw data -  (36, 640, 320) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 297 \file1000806.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 298 \file1000807.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 299 \file1000808.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 300 \file1000814.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 301 \file1000819.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 302 \file1000821.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 303 \file1000824.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 304 \file1000827.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 305 \file1000829.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 306 \file1000830.h5 raw data -  (41, 640, 368) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 307 \file1000833.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 308 \file1000834.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 309 \file1000836.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 310 \file1000846.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 311 \file1000848.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 312 \file1000850.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 313 \file1000851.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 314 \file1000856.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 315 \file1000859.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 316 \file1000863.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 317 \file1000865.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 318 \file1000873.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 319 \file1000874.h5 raw data -  (38, 640, 372) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 320 \file1000875.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 321 \file1000876.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 322 \file1000880.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 323 \file1000882.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 324 \file1000883.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 325 \file1000884.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 326 \file1000888.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 327 \file1000896.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 328 \file1000898.h5 raw data -  (32, 640, 322) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 329 \file1000904.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 330 \file1000914.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 331 \file1000919.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 332 \file1000922.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 333 \file1000927.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 334 \file1000929.h5 raw data -  (39, 640, 386) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 335 \file1000931.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 336 \file1000933.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 337 \file1000936.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 338 \file1000941.h5 raw data -  (32, 640, 388) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 339 \file1000943.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 340 \file1000947.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 341 \file1000952.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 342 \file1000954.h5 raw data -  (33, 640, 322) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 343 \file1000955.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 344 \file1000956.h5 raw data -  (44, 640, 388) -- input volume -  (44, 320, 320) -- output volume -  (44, 320, 320)
# 345 \file1000959.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 346 \file1000962.h5 raw data -  (50, 640, 368) -- input volume -  (50, 320, 320) -- output volume -  (50, 320, 320)
# 347 \file1000963.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 348 \file1000964.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 349 \file1000967.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 350 \file1000968.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 351 \file1000969.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 352 \file1000970.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 353 \file1000971.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 354 \file1000973.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 355 \file1000974.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 356 \file1000981.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 357 \file1000983.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 358 \file1000984.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 359 \file1000985.h5 raw data -  (35, 640, 372) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 360 \file1000988.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 361 \file1000994.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 362 \file1000995.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 363 \file1000997.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 364 \file1000999.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 365 \file1001001.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 366 \file1001003.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 367 \file1001004.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 368 \file1001005.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 369 \file1001006.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 370 \file1001007.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 371 \file1001008.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 372 \file1001013.h5 raw data -  (33, 640, 322) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 373 \file1001014.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 374 \file1001022.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 375 \file1001023.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 376 \file1001024.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 377 \file1001026.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 378 \file1001027.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 379 \file1001029.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 380 \file1001033.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 381 \file1001036.h5 raw data -  (30, 640, 368) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 382 \file1001037.h5 raw data -  (42, 640, 372) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 383 \file1001042.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 384 \file1001048.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 385 \file1001051.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 386 \file1001053.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 387 \file1001056.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 388 \file1001061.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 389 \file1001062.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 390 \file1001067.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 391 \file1001071.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 392 \file1001079.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 393 \file1001082.h5 raw data -  (38, 640, 400) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 394 \file1001084.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 395 \file1001087.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 396 \file1001092.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 397 \file1001094.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 398 \file1001098.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 399 \file1001099.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 400 \file1001101.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 401 \file1001102.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 402 \file1001106.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 403 \file1001108.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 404 \file1001109.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 405 \file1001110.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 406 \file1001113.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 407 \file1001114.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 408 \file1001116.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 409 \file1001120.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 410 \file1001121.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 411 \file1001130.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 412 \file1001131.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 413 \file1001134.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 414 \file1001139.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# ...
# 837 \file1002238.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 838 \file1002239.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 839 \file1002241.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 840 \file1002243.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 841 \file1002244.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 842 \file1002245.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 843 \file1002246.h5 raw data -  (30, 640, 322) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 844 \file1002247.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 845 \file1002251.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 846 \file1002256.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 847 \file1002262.h5 raw data -  (42, 640, 372) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 848 \file1002263.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 849 \file1002264.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 850 \file1002266.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 851 \file1002269.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 852 \file1002271.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 853 \file1002273.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 854 \file1002276.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 855 \file1002283.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 856 \file1002284.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 857 \file1002286.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 858 \file1002287.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 859 \file1002293.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 860 \file1002296.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 861 \file1002298.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 862 \file1002300.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 863 \file1002303.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 864 \file1002304.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 865 \file1002307.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 866 \file1002309.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 867 \file1002315.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 868 \file1002324.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 869 \file1002325.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 870 \file1002326.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 871 \file1002332.h5 raw data -  (45, 640, 368) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 872 \file1002333.h5 raw data -  (42, 640, 368) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 873 \file1002334.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 874 \file1002335.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 875 \file1002338.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 876 \file1002341.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 877 \file1002342.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 878 \file1002343.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 879 \file1002352.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 880 \file1002353.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 881 \file1002354.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 882 \file1002356.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 883 \file1002357.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 884 \file1002358.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 885 \file1002359.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 886 \file1002361.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 887 \file1002363.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 888 \file1002366.h5 raw data -  (37, 640, 372) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 889 \file1002367.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 890 \file1002368.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 891 \file1002369.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 892 \file1002371.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 893 \file1002374.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 894 \file1002376.h5 raw data -  (28, 640, 372) -- input volume -  (28, 320, 320) -- output volume -  (28, 320, 320)
# 895 \file1002378.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 896 \file1002379.h5 raw data -  (45, 640, 368) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 897 \file1002381.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 898 \file1002383.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 899 \file1002385.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 900 \file1002386.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 901 \file1002388.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 902 \file1002395.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 903 \file1002396.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 904 \file1002397.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 905 \file1002399.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 906 \file1002407.h5 raw data -  (34, 640, 550) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 907 \file1002409.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 908 \file1002416.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 909 \file1002422.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 910 \file1002423.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 911 \file1002425.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 912 \file1002430.h5 raw data -  (31, 640, 368) -- input volume -  (31, 320, 320) -- output volume -  (31, 320, 320)
# 913 \file1002431.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 914 \file1002432.h5 raw data -  (34, 640, 368) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 915 \file1002434.h5 raw data -  (33, 640, 320) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 916 \file1002435.h5 raw data -  (39, 640, 388) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 917 \file1002437.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 918 \file1002439.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 919 \file1002440.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 920 \file1002441.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 921 \file1002444.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 922 \file1002449.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 923 \file1002455.h5 raw data -  (41, 640, 356) -- input volume -  (41, 320, 320) -- output volume -  (41, 320, 320)
# 924 \file1002456.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 925 \file1002458.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 926 \file1002459.h5 raw data -  (42, 640, 372) -- input volume -  (42, 320, 320) -- output volume -  (42, 320, 320)
# 927 \file1002461.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 928 \file1002462.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 929 \file1002469.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 930 \file1002471.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 931 \file1002473.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 932 \file1002474.h5 raw data -  (32, 640, 368) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 933 \file1002475.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 934 \file1002476.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 935 \file1002478.h5 raw data -  (38, 640, 372) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 936 \file1002479.h5 raw data -  (28, 640, 372) -- input volume -  (28, 320, 320) -- output volume -  (28, 320, 320)
# 937 \file1002481.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 938 \file1002485.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 939 \file1002491.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 940 \file1002492.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 941 \file1002494.h5 raw data -  (33, 640, 368) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 942 \file1002495.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 943 \file1002497.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 944 \file1002499.h5 raw data -  (36, 640, 372) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 945 \file1002500.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 946 \file1002505.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 947 \file1002509.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 948 \file1002510.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 949 \file1002511.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 950 \file1002514.h5 raw data -  (39, 640, 368) -- input volume -  (39, 320, 320) -- output volume -  (39, 320, 320)
# 951 \file1002516.h5 raw data -  (37, 640, 368) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 952 \file1002517.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 953 \file1002518.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 954 \file1002520.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 955 \file1002521.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 956 \file1002523.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 957 \file1002531.h5 raw data -  (37, 640, 386) -- input volume -  (37, 320, 320) -- output volume -  (37, 320, 320)
# 958 \file1002532.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 959 \file1002534.h5 raw data -  (30, 640, 372) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 960 \file1002537.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 961 \file1002541.h5 raw data -  (38, 640, 368) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 962 \file1002542.h5 raw data -  (34, 640, 372) -- input volume -  (34, 320, 320) -- output volume -  (34, 320, 320)
# 963 \file1002543.h5 raw data -  (33, 640, 372) -- input volume -  (33, 320, 320) -- output volume -  (33, 320, 320)
# 964 \file1002544.h5 raw data -  (35, 640, 368) -- input volume -  (35, 320, 320) -- output volume -  (35, 320, 320)
# 965 \file1002545.h5 raw data -  (36, 640, 320) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 966 \file1002549.h5 raw data -  (30, 640, 322) -- input volume -  (30, 320, 320) -- output volume -  (30, 320, 320)
# 967 \file1002554.h5 raw data -  (36, 640, 368) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)
# 968 \file1002561.h5 raw data -  (32, 640, 372) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 969 \file1002563.h5 raw data -  (32, 640, 368) -- input volume -  (32, 320, 320) -- output volume -  (32, 320, 320)
# 970 \file1002566.h5 raw data -  (38, 640, 320) -- input volume -  (38, 320, 320) -- output volume -  (38, 320, 320)
# 971 \file1002567.h5 raw data -  (45, 640, 368) -- input volume -  (45, 320, 320) -- output volume -  (45, 320, 320)
# 972 \file1002568.h5 raw data -  (40, 640, 368) -- input volume -  (40, 320, 320) -- output volume -  (40, 320, 320)
# 973 \file1002569.h5 raw data -  (36, 640, 356) -- input volume -  (36, 320, 320) -- output volume -  (36, 320, 320)

# %% [markdown]
# ### Sanity check

# %%
len(os.listdir(LOW_DIR_PATH)), len(os.listdir(HIGH_DIR_PATH))
# Out:
# (973, 973)

# %%
# remember to read data in same sequence to retain x,y mapping for each MRI scan
os.listdir(LOW_DIR_PATH)[:3], os.listdir(HIGH_DIR_PATH)[:3]
# Out:
# (['1.npy', '10.npy', '100.npy'], ['1.npy', '10.npy', '100.npy'])

# %%
print("Done!")
# Out:
# Done!
