# %%
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
hf = h5py.File("file1000022_v2.h5")
print(type(hf))
# Out:
# <class 'h5py._hl.files.File'>

# %%
print('Keys:', list(hf.keys()))
print('Attrs:', dict(hf.attrs))
# Out:
# Keys: ['reconstruction']
# Attrs: {}

# %%
v_k = hf['reconstruction'][()]
print(v_k.shape)
# Out:
# (37, 320, 320)

# %%
type(v_k)
# Out:
# numpy.ndarray

# %%
v_k[10,:,:].shape
# Out:
# (320, 320)

# %%
plt.imshow(v_k[24,:,:], cmap='gray')

# %%
a = v_k[0,:,:]
a
# Out:
# array([[0.04924449, 0.02666857, 0.0498132 , ..., 0.04989852, 0.02535854,
#         0.04824202],
#        [0.07471194, 0.03469839, 0.03666407, ..., 0.02531913, 0.02799124,
#         0.01648143],
#        [0.05727238, 0.03831756, 0.03373824, ..., 0.02233763, 0.04194079,
#         0.04572824],
#        ...,
#        [0.01213822, 0.02173288, 0.06011255, ..., 0.03311437, 0.03313172,
#         0.02520848],
#        [0.02804631, 0.03932763, 0.0453732 , ..., 0.03325515, 0.03640505,
#         0.0612005 ],
#        [0.02490692, 0.02638153, 0.01647903, ..., 0.05930942, 0.03930509,
#         0.0274475 ]], dtype=float32)

# %%
max(a.flatten()), min(a.flatten())
# Out:
# (0.85901564, -0.004145142)
